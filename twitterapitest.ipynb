# %%
import sys
# !{sys.executable} -m pip install tweepy

# %%
import tweepy

# %%
bearer_token = "AAAAAAAAAAAAAAAAAAAAANi8cwEAAAAA7kARfRwpy18BXrTzpD2utAoBGJs%3DE2ykmCGvP6Cwa4JZ9VIFiuJ1fcUPtdqtrZ2pr7ehtiFQ7Rfi2p"
# Have to save everything as environmental variables -> put that on the to-do list 

client = tweepy.Client(bearer_token=bearer_token)

# query to search for tweets
query = "#Roe v Wade lang:en -is:retweet"
# your start and end time for fetching tweets
start_time = "2022-5-19T00:00:00Z"
end_time = "2022-5-25T00:00:00Z"
# get tweets from the API
tweets = client.search_recent_tweets(query=query,
                                     start_time=start_time,
                                     end_time=end_time,
                                     tweet_fields = ["created_at", "text", "source"],
                                     user_fields = ["name", "username", "location", "verified", "description"],
                                     max_results = 100,
                                     expansions='author_id'
                                     )

print(tweets)
# Out:
# Response(data=[<Tweet id=1529171375004520449 text='Nearly 50 years ago the U.S. Supreme Court’s ruling in #RoevWade recognized that the decision whether or not to continue a pregnancy belongs to the individual, not the government. Now, #Roe and that fundamental right are on the line. #AbortionIsEssential\nhttps://t.co/DhBzdyAb6F'>, <Tweet id=1529167093408665604 text='Pro-Choice Voters’ Response To ‘Roe V. Wade’ Potential Overturn Could Help California Democrats\n#Roe #AbortionLaws #CaliforniaPolitics  \nhttps://t.co/kPl9vIAS2P'>, <Tweet id=1529157516676014081 text='“Instead,\xa0the court\xa0made a political decision\xa0to take up cases designed by anti-abortion groups and their political allies in\xa0state\xa0government\xa0to intentionally\xa0undermine Roe v. Wade.” #roe https://t.co/sIrk3KiiAN'>, <Tweet id=1529153971377479680 text='Pence prays Supreme Court justices have courage of their convictions to overturn Roe v. Wade... https://t.co/c31y2lagZb #pence #prays #supreme #court #ju
# ...

# %%
tweet_list = []

for i in range(len(tweets.data)):
    tweet_list.append(dict(tweets.data[i]))
tweet_list
# Out:
# [{'source': 'Sprout Social',
#   'id': 1529171375004520449,
#   'text': 'Nearly 50 years ago the U.S. Supreme Court’s ruling in #RoevWade recognized that the decision whether or not to continue a pregnancy belongs to the individual, not the government. Now, #Roe and that fundamental right are on the line. #AbortionIsEssential\nhttps://t.co/DhBzdyAb6F',
#   'author_id': 50310311,
#   'created_at': datetime.datetime(2022, 5, 24, 18, 44, 1, tzinfo=datetime.timezone.utc)},
#  {'source': 'Twitter Web App',
#   'id': 1529167093408665604,
#   'text': 'Pro-Choice Voters’ Response To ‘Roe V. Wade’ Potential Overturn Could Help California Democrats\n#Roe #AbortionLaws #CaliforniaPolitics  \nhttps://t.co/kPl9vIAS2P',
#   'author_id': 915002523584487424,
#   'created_at': datetime.datetime(2022, 5, 24, 18, 27, tzinfo=datetime.timezone.utc)},
#  {'source': 'Twitter for iPhone',
#   'id': 1529157516676014081,
# ...

# %%
len(tweet_list)
# Out:
# 48

# %%
# import the pandas library
import pandas as pd
# create a list of records
tweet_info_ls = []
# iterate over each tweet and corresponding user details
for tweet in tweets.data:
    tweet_info = {
        'created_at': tweet.created_at,
        'text': tweet.text,
        'source': tweet.source,
    }
    tweet_info_ls.append(tweet_info)
# create dataframe from the extracted records
tweets_df = pd.DataFrame(tweet_info_ls)
# display the dataframe
tweets_df.head()
# Out:
#                  created_at  \
# 0 2022-05-24 18:44:01+00:00
# 1 2022-05-24 18:27:00+00:00
# 2 2022-05-24 17:48:57+00:00
# 3 2022-05-24 17:34:51+00:00
# 4 2022-05-24 15:57:27+00:00
#
#                                                 text              source
# 0  Nearly 50 years ago the U.S. Supreme Court’s r...       Sprout Social
# 1  Pro-Choice Voters’ Response To ‘Roe V. Wade’ P...     Twitter Web App
# 2  “Instead, the court made a political decision ...  Twitter for iPhone
# 3  Pence prays Supreme Court justices have courag...       AnyPoll Links
# 4  Cronenberg weighs in on Roe v. Wade turmoil at...       WordPress.com

# %%
api_key = "RAjkxSnnqMx3HGKjrmJPRzErp"
api_secrets = "R32g05QzuNrJ2MnPnn2miOjsf6DYH2BBjEucAS27kaOnpZeM6T"
access_token = "1477907560103493634-A5vNs4kJ1J0XLwNJLLPasr2bxlX1cJ"
access_secret = "Z8e9j3u89Us8rZpu9fsCm6cUoy1irAjV8LYnSeWoQe7fR"

# Read via .env file -> check this later to ensure tokens aren't in code
# https://www.jcchouinard.com/how-to-use-twitter-api-with-python/ -> convert to json and put in gitignore 

#! Already regenerated tokens but still failing authentication 

{"token_type":"bearer","access_token":"AAAAAAAAAAAAAAAAAAAAANi8cwEAAAAA7kARfRwpy18BXrTzpD2utAoBGJs%3DE2ykmCGvP6Cwa4JZ9VIFiuJ1fcUPtdqtrZ2pr7ehtiFQ7Rfi2p"}

auth = tweepy.OAuthHandler(api_key,api_secrets) # use application authentication instead of user authentication
auth.set_access_token(access_token,access_secret)

api = tweepy.API(auth) 

try:
    api.verify_credentials()
    print('Successful Authentication')
except:
    print('Failed authentication')
# Out:
# Failed authentication

# %% [markdown]
# 1. Find a way to read tweets and accumulate them into a list/array
# 2.

# %%
# Current shell API call to verify for a single predetermined tweet:


# curl "https://api.twitter.com/2/tweets?ids=1261326399320715264,1278347468690915330" \
#   -H "Authorization: Bearer AAAAAAAAAAAAAAAAAAAAANi8cwEAAAAA7kARfRwpy18BXrTzpD2utAoBGJs%3DE2ykmCGvP6Cwa4JZ9VIFiuJ1fcUPtdqtrZ2pr7ehtiFQ7Rfi2p"
# api = tweepy.API(auth)

# %%
# Attempting to post
status = "This is my first post to Twitter using the API. I am still learning, please be kind :)"
api.update_status(status=status)
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# /Users/kanishsharma/Downloads/Computer Science/Netsolutions - Internship/twitterapitest.ipynb Cell 5' in <module>
#       <a href='vscode-notebook-cell:/Users/kanishsharma/Downloads/Computer%20Science/Netsolutions%20-%20Internship/twitterapitest.ipynb#ch0000005?line=0'>1</a> # Attempting to post
#       <a href='vscode-notebook-cell:/Users/kanishsharma/Downloads/Computer%20Science/Netsolutions%20-%20Internship/twitterapitest.ipynb#ch0000005?line=1'>2</a> status = "This is my first post to Twitter using the API. I am still learning, please be kind :)"
# ----> <a href='vscode-notebook-cell:/Users/kanishsharma/Downloads/Computer%20Science/Netsolutions%20-%20Internship/twitterapitest.ipynb#ch0000005?line=2'>3</a> api.update_status(status=status)
#
# ...
